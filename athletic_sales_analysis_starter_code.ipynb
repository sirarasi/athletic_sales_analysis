# %%
# Import Libraries and Dependencies
import pandas as pd

# %% [markdown]
# ### 1. Combine and Clean the Data
# #### Import CSVs

# %%
# Read the CSV files into DataFrames.
athletic_sales_2020_df = pd.read_csv('Resources/athletic_sales_2020.csv')
athletic_sales_2021_df = pd.read_csv('Resources/athletic_sales_2021.csv')

# %%
# Display the 2020 sales DataFrame
athletic_sales_2020_df
# Out:
#          retailer  retailer_id invoice_date     region         state  \
# 0     Foot Locker      1185732       1/1/20  Northeast      New York
# 1     Foot Locker      1185732       1/1/20  Northeast  Pennsylvania
# 2     Foot Locker      1185732       1/1/20  Northeast  Pennsylvania
# 3     Foot Locker      1185732       1/1/20  Northeast      New York
# 4     Foot Locker      1185732       1/1/20  Northeast  Pennsylvania
# ...           ...          ...          ...        ...           ...
# 1292    West Gear      1128299     12/30/20       West    California
# 1293    West Gear      1128299     12/30/20       West    California
# 1294       Kohl's      1189833     12/30/20    Midwest     Minnesota
# 1295       Kohl's      1189833     12/30/20    Midwest     Minnesota
# 1296    West Gear      1128299     12/30/20       West    California
#
#                city                  product  price_per_unit  units_sold  \
# ...

# %%
# Display the 2021 sales DataFrame
athletic_sales_2021_df
# Out:
#          retailer  retailer_id invoice_date     region         state  \
# 0       West Gear      1128299       1/1/21       West    California
# 1       West Gear      1128299       1/1/21       West    California
# 2          Kohl's      1189833       1/1/21    Midwest       Montana
# 3          Kohl's      1189833       1/1/21    Midwest       Montana
# 4       West Gear      1128299       1/1/21       West    California
# ...           ...          ...          ...        ...           ...
# 8341  Foot Locker      1185732     12/31/21  Northeast  Pennsylvania
# 8342  Foot Locker      1185732     12/31/21  Northeast  Pennsylvania
# 8343       Amazon      1185732     12/31/21  Northeast         Maine
# 8344       Amazon      1185732     12/31/21  Northeast         Maine
# 8345  Foot Locker      1185732     12/31/21  Northeast  Pennsylvania
#
#                city                  product  price_per_unit  units_sold  \
# ...

# %% [markdown]
# #### Check the data types of each DataFrame

# %%
# Check the 2020 sales data types.
athletic_sales_2020_df.dtypes
# Out:
# retailer             object
# retailer_id           int64
# invoice_date         object
# region               object
# state                object
# city                 object
# product              object
# price_per_unit        int64
# units_sold            int64
# total_sales           int64
# operating_profit    float64
# sales_method         object
# dtype: object

# %%
# Check the 2021 sales data types.
athletic_sales_2021_df.dtypes
# Out:
# retailer             object
# retailer_id           int64
# invoice_date         object
# region               object
# state                object
# city                 object
# product              object
# price_per_unit        int64
# units_sold            int64
# total_sales           int64
# operating_profit    float64
# sales_method         object
# dtype: object

# %% [markdown]
# #### Combine the sales data by rows.

# %%
# Combine the 2020 and 2021 sales DataFrames on the rows and reset the index.
joined_sales_2020_2021_rows = pd.concat([athletic_sales_2020_df, athletic_sales_2021_df], axis="rows", join="inner")
#joined_sales_2020_2021_rows.head(30)
joined_sales_2020_2021_rows = joined_sales_2020_2021_rows.reset_index(drop=True)
joined_sales_2020_2021_rows.head(30)
#joined_sales_2020_2021_rows.tail()
# Out:
#        retailer  retailer_id invoice_date     region         state  \
# 0   Foot Locker      1185732       1/1/20  Northeast      New York
# 1   Foot Locker      1185732       1/1/20  Northeast  Pennsylvania
# 2   Foot Locker      1185732       1/1/20  Northeast  Pennsylvania
# 3   Foot Locker      1185732       1/1/20  Northeast      New York
# 4   Foot Locker      1185732       1/1/20  Northeast  Pennsylvania
# 5   Foot Locker      1185732       1/1/20  Northeast      New York
# 6     West Gear      1128299       1/2/20  Northeast  Pennsylvania
# 7     West Gear      1128299       1/2/20  Northeast  Pennsylvania
# 8   Foot Locker      1185732       1/2/20  Northeast      New York
# 9     West Gear      1128299       1/2/20  Northeast  Pennsylvania
# 10  Foot Locker      1185732       1/2/20  Northeast      New York
# 11  Foot Locker      1185732       1/2/20  Northeast      New York
# 12    West Gear      1128299       1/3/20  Northeast  Pennsylvania
# ...

# %%
# Check if any values are null.
joined_sales_2020_2021_rows.isna().sum()
# Out:
# retailer            0
# retailer_id         0
# invoice_date        0
# region              0
# state               0
# city                0
# product             0
# price_per_unit      0
# units_sold          0
# total_sales         0
# operating_profit    0
# sales_method        0
# dtype: int64

# %%
# Check the data type of each column
joined_sales_2020_2021_rows.dtypes
# Out:
# retailer             object
# retailer_id           int64
# invoice_date         object
# region               object
# state                object
# city                 object
# product              object
# price_per_unit        int64
# units_sold            int64
# total_sales           int64
# operating_profit    float64
# sales_method         object
# dtype: object

# %%
joined_sales_2020_2021_rows["invoice_date"].dtype
joined_sales_2020_2021_rows["invoice_date"].head(5)
# Out:
# 0    1/1/20
# 1    1/1/20
# 2    1/1/20
# 3    1/1/20
# 4    1/1/20
# Name: invoice_date, dtype: object

# %%
# Convert the "invoice_date" to a datetime datatype
joined_sales_2020_2021_rows["invoice_date"] = pd.to_datetime(joined_sales_2020_2021_rows["invoice_date"],dayfirst=False, format="%m/%d/%y",errors="coerce")
#joined_sales_2020_2021_rows["invoice_date"] = pd.to_datetime(joined_sales_2020_2021_rows["invoice_date"],dayfirst=False,format="mixed")
#joined_sales_2020_2021_rows["invoice_date"] = pd.to_datetime(joined_sales_2020_2021_rows["invoice_date"],errors="coerce")
joined_sales_2020_2021_rows["invoice_date"].dtype
joined_sales_2020_2021_rows["invoice_date"].head(5)
# Out:
# 0   2020-01-01
# 1   2020-01-01
# 2   2020-01-01
# 3   2020-01-01
# 4   2020-01-01
# Name: invoice_date, dtype: datetime64[ns]

# %%
# Confirm that the "invoice_date" data type has been changed.
joined_sales_2020_2021_rows.dtypes
# Out:
# retailer                    object
# retailer_id                  int64
# invoice_date        datetime64[ns]
# region                      object
# state                       object
# city                        object
# product                     object
# price_per_unit               int64
# units_sold                   int64
# total_sales                  int64
# operating_profit           float64
# sales_method                object
# dtype: object

# %% [markdown]
# ### 2. Determine which Region Sold the Most Products

# %% [markdown]
# #### Using `groupby`

# %%
# Show the number products sold for region, state, and city.
# Rename the sum to "Total_Products_Sold".
groupby_region_state_city_products_sold = joined_sales_2020_2021_rows.groupby(['region', 'state', 'city'])[['units_sold']].agg('sum')
               
groupby_Total_Products_Sold_Column = groupby_region_state_city_products_sold.rename(columns={"units_sold": "Total_Products_Sold"})                                

Groupby_Top_Regions = groupby_Total_Products_Sold_Column.sort_values(by=["Total_Products_Sold"], ascending=False)

# Show the top 5 results.
Groupby_Top_Regions.head(5)
# Out:
#                                     Total_Products_Sold
# region    state      city
# Northeast New York   New York                    111954
# South     Texas      Houston                      90322
# West      California San Francisco                85478
#                      Los Angeles                  76384
# Southeast Florida    Miami                        73135

# %% [markdown]
# #### Using `pivot_table`

# %%
# Show the number products sold for region, state, and city.
region_state_city_products_sold = pd.pivot_table(joined_sales_2020_2021_rows, 
                                 index=['region', 'state', 'city'],
                                 values='units_sold',
                                 aggfunc='sum')

# Rename the "units_sold" column to "Total_Products_Sold"

Total_Products_Sold_Column = region_state_city_products_sold.rename(columns={"units_sold": "Total_Products_Sold"})

# Sort the renamed pivot table in ascending order to show the top five regions,
# including the state and city that have the greatest number of products sold .
Top_Regions = Total_Products_Sold_Column.sort_values(by=["Total_Products_Sold"], ascending=False)

# Show the top 5 results.
Top_Regions.head(5)
# Out:
#                                     Total_Products_Sold
# region    state      city
# Northeast New York   New York                    111954
# South     Texas      Houston                      90322
# West      California San Francisco                85478
#                      Los Angeles                  76384
# Southeast Florida    Miami                        73135

# %% [markdown]
# ### 3. Determine which Region had the Most Sales

# %% [markdown]
# #### Using `groupby`

# %%
# Show the total sales for the products sold for each region, state, and city.
groupby_region_state_city_sales = joined_sales_2020_2021_rows.groupby(['region', 'state', 'city'])[['total_sales']].agg('sum')

# Rename the "total_sales" column to "Total Sales"
groupby_Total_Sales_Column = groupby_region_state_city_sales.rename(columns={"total_sales": "Total Sales"})

# Sort the results in ascending order to show the top five regions,
# including the state and city that generated the most sales.
groupby_Top_Regions_Sales = groupby_Total_Sales_Column.sort_values(by=["Total Sales"], ascending=False)

# Show the top 5 results.
groupby_Top_Regions_Sales.head(5)
# Out:
#                                         Total Sales
# region    state          city
# Northeast New York       New York          39801235
# West      California     San Francisco     33973228
# Southeast Florida        Miami             31600863
#           South Carolina Charleston        29285637
#           Florida        Orlando           27682851

# %% [markdown]
# #### Using `pivot_table`

# %%
# Show the total sales for the products sold for each region, state, and city.
region_state_city_sales = pd.pivot_table(joined_sales_2020_2021_rows, 
                                 index=['region', 'state', 'city'],
                                 values='total_sales',
                                 aggfunc='sum')

# Optional: Rename the "total_sales" column to "Total Sales"
Total_Sales_Column = region_state_city_sales.rename(columns={"total_sales": "Total Sales"})

# Sort the results in ascending order to show the top five regions,
# including the state and city that generated the most sales.
Top_Regions_Sales = Total_Sales_Column.sort_values(by=["Total Sales"], ascending=False)

# Show the top 5 results.
Top_Regions_Sales.head(5)
# Out:
#                                         Total Sales
# region    state          city
# Northeast New York       New York          39801235
# West      California     San Francisco     33973228
# Southeast Florida        Miami             31600863
#           South Carolina Charleston        29285637
#           Florida        Orlando           27682851

# %% [markdown]
# ### 4. Determine which Retailer had the Most Sales

# %% [markdown]
# #### Using `groupby`

# %%
# Show the total sales for the products sold for each retailer, region, state, and city.
groupby_retailer_region_state_city_sales = joined_sales_2020_2021_rows.groupby(['retailer','region', 'state', 'city'])[['total_sales']].agg('sum')

# Rename the "total_sales" column to "Total Sales"
groupby_Retailer_Total_Sales_Column = groupby_retailer_region_state_city_sales.rename(columns={"total_sales": "Total Sales"})

# Sort the results in ascending order to show the top five retailers along with their,
# region, state and city that generated the most sales.
groupby_Top_Retailer_Sales = groupby_Retailer_Total_Sales_Column.sort_values(by=["Total Sales"], ascending=False)

# Show the top 5 results.
groupby_Top_Retailer_Sales.head(5)
# Out:
#                                                     Total Sales
# retailer    region    state          city
# West Gear   West      California     San Francisco     32794405
# Kohl's      West      California     Los Angeles       25127160
# Foot Locker Northeast New York       New York          25008568
# West Gear   West      Washington     Seattle           24862675
# Foot Locker Southeast South Carolina Charleston        24822280

# %% [markdown]
# #### Using `pivot_table`

# %%
# Show the total sales for the products sold for each retailer, region, state, and city.
retailer_region_state_city_sales = pd.pivot_table(joined_sales_2020_2021_rows, 
                                 index=['retailer', 'region', 'state', 'city'],
                                 values='total_sales',
                                 aggfunc='sum')


# Optional: Rename the "total_sales" column to "Total Sales"
Retailer_Total_Sales_Column = retailer_region_state_city_sales.rename(columns={"total_sales": "Total Sales"})

# Sort the results in ascending order to show the top five retailers along with their,
# region, state and city that generated the most sales.
Top_Retailer_Sales = Retailer_Total_Sales_Column.sort_values(by=["Total Sales"], ascending=False)

# Show the top 5 results.
Top_Retailer_Sales.head(5)
# Out:
#                                                     Total Sales
# retailer    region    state          city
# West Gear   West      California     San Francisco     32794405
# Kohl's      West      California     Los Angeles       25127160
# Foot Locker Northeast New York       New York          25008568
# West Gear   West      Washington     Seattle           24862675
# Foot Locker Southeast South Carolina Charleston        24822280

# %% [markdown]
# ### 5. Determine which Retailer Sold the Most Women's Athletic Footwear

# %%
# Filter the sales data to get the women's athletic footwear sales data.
Womens_Athletic_Footwear_only = joined_sales_2020_2021_rows.loc[(joined_sales_2020_2021_rows["product"]=="Women's Athletic Footwear")]
Womens_Athletic_Footwear_only.head(5)
# Out:
#        retailer  retailer_id invoice_date     region         state  \
# 21  Foot Locker      1185732   2020-01-04  Northeast      New York
# 22  Foot Locker      1185732   2020-01-04  Northeast      New York
# 23  Foot Locker      1185732   2020-01-04  Northeast      New York
# 26    West Gear      1128299   2020-01-05  Northeast  Pennsylvania
# 27    West Gear      1128299   2020-01-05  Northeast  Pennsylvania
#
#             city                    product  price_per_unit  units_sold  \
# 21      New York  Women's Athletic Footwear              36         281
# 22      New York  Women's Athletic Footwear              41         247
# 23      New York  Women's Athletic Footwear              45         850
# 26  Philadelphia  Women's Athletic Footwear              45         300
# 27  Philadelphia  Women's Athletic Footwear              34          90
#
#     total_sales  operating_profit sales_method
# 21        10116           3742.92       Outlet
# ...

# %% [markdown]
# #### Using `groupby`

# %%
#Show the total number of women's athletic footwear sold for each retailer, region, state, and city.
groupby_Units_Women_Athletic_Footwear_sales = Womens_Athletic_Footwear_only.groupby(['retailer','region', 'state', 'city'])[['units_sold']].agg('sum')

# Rename the "units_sold" column to "Womens_Footwear_Units_Sold"
groupby_Total_WAF_Unit_Column = groupby_Units_Women_Athletic_Footwear_sales.rename(columns={"units_sold": "Womens_Footwear_Units_Sold"})

# Sort the results in ascending order to show the top five retailers along with their,
# region, state and city that sold the most women's athletic footwear.
groupby_Top_WAF_Unit_Sales = groupby_Total_WAF_Unit_Column.sort_values(by=["Womens_Footwear_Units_Sold"], ascending=False)

# Show the top 5 results.
groupby_Top_WAF_Unit_Sales.head(5)
# Out:
#                                                       Womens_Footwear_Units_Sold
# retailer      region    state          city
# West Gear     West      California     San Francisco                       12107
# Foot Locker   Northeast New York       New York                            10996
# Kohl's        West      California     Los Angeles                         10826
# Foot Locker   Southeast South Carolina Charleston                           8814
# Sports Direct South     Texas          Dallas                               8790

# %% [markdown]
# #### Using `pivot_table`

# %%
#Show the total number of women's athletic footwear sold for each retailer, region, state, and city.
Units_Women_Athletic_Footwear_sales = pd.pivot_table(Womens_Athletic_Footwear_only, 
                                 index=['retailer', 'region', 'state', 'city'],
                                 values='units_sold',
                                 aggfunc='sum')

# Rename the "units_sold" column to "Womens_Footwear_Units_Sold"
Total_WAF_Unit_Column = Units_Women_Athletic_Footwear_sales.rename(columns={"units_sold": "Womens_Footwear_Units_Sold"})

# Sort the results in ascending order to show the top five retailers along with their,
# region, state and city that sold the most women's athletic footwear.
Top_WAF_Unit_Sales = Total_WAF_Unit_Column.sort_values(by=["Womens_Footwear_Units_Sold"], ascending=False)

# Show the top 5 results.
Top_WAF_Unit_Sales.head(5)
# Out:
#                                                       Womens_Footwear_Units_Sold
# retailer      region    state          city
# West Gear     West      California     San Francisco                       12107
# Foot Locker   Northeast New York       New York                            10996
# Kohl's        West      California     Los Angeles                         10826
# Foot Locker   Southeast South Carolina Charleston                           8814
# Sports Direct South     Texas          Dallas                               8790

# %% [markdown]
# ### 5. Determine the Day with the Most Women's Athletic Footwear Sales

# %%
# Create a pivot table with the 'invoice_date' column is the index, and the "total_sales" as the values.
Invoice_Women_Athletic_Footwear_sales = pd.pivot_table(Womens_Athletic_Footwear_only, 
                                 index=['invoice_date'],
                                 values='total_sales',
                                 aggfunc='sum')

# Optional: Rename the "total_sales" column to "Total Sales"
Total_WAF_Invoice_Sales_Column = Invoice_Women_Athletic_Footwear_sales.rename(columns={"total_sales": "Total Sales"})

# Show the table.
Total_WAF_Invoice_Sales_Column
# Out:
#               Total Sales
# invoice_date
# 2020-01-04         402743
# 2020-01-05         141801
# 2020-01-11         129556
# 2020-01-17         173013
# 2020-01-22         388250
# ...                   ...
# 2021-12-22         200406
# 2021-12-23         808022
# 2021-12-24         190885
# 2021-12-25         315175
# 2021-12-30         167903
#
# [355 rows x 1 columns]

# %%
# Resample the pivot table into daily bins, and get the total sales for each day.

Total_sales_foreachday = Total_WAF_Invoice_Sales_Column.resample('D').sum()

# Sort the resampled pivot table in ascending order on "Total Sales".
Top_WAF_resample_Day_Sales = Total_sales_foreachday.sort_values(by=["Total Sales"], ascending=False)

# Show the top 10 results.
Top_WAF_resample_Day_Sales.head(10)
# Out:
#               Total Sales
# invoice_date
# 2021-07-16        1521825
# 2021-12-16        1473497
# 2021-06-17        1376988
# 2021-08-17        1086294
# 2021-07-23        1021806
# 2021-11-17        1021145
# 2021-12-09         915011
# 2021-06-24         884238
# 2021-07-09         869054
# 2021-08-10         839120

# %% [markdown]
# ### 6.  Determine the Week with the Most Women's Athletic Footwear Sales

# %%
# Resample the pivot table into weekly bins, and get the total sales for each week.
Total_sales_foreachweek = Total_WAF_Invoice_Sales_Column.resample('W').sum()

# Sort the resampled pivot table in ascending order on "Total Sales".
Top_WAF_resample_Week_Sales = Total_sales_foreachweek.sort_values(by=["Total Sales"], ascending=False)

# Show the top 10 results.
Top_WAF_resample_Week_Sales.head(10)
# Out:
#               Total Sales
# invoice_date
# 2021-12-19        3098970
# 2021-12-12        2922161
# 2021-07-11        2835078
# 2021-07-18        2801449
# 2021-11-14        2531721
# 2021-08-22        2491259
# 2021-08-15        2463941
# 2021-11-21        2449537
# 2021-05-16        2422132
# 2021-06-13        2358602
